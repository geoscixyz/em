# %% [markdown]
# # Harmonic Magnetic Dipole
#
# If you run into import errors, try running `pip install -r requirements.txt` inside the examples directory.
#
# The source code is in http://docs.simpeg.xyz

# %%
from SimPEG import *
from SimPEG.Examples import EM_Analytic_MagDipoleWholespace as MagDipole


from ipywidgets import interactive, IntSlider, widget, FloatText, FloatSlider, ToggleButtons #interactive plots!

# %matplotlib inline

# %% [markdown]
# ## This is the figure in em.geosci.xyz

# %%
fig, ax = MagDipole.run()
# fig.savefig('../../content/maxwell1_fundamentals/images/MagDipoleWholeSpace.png',dpi=100)

# %% [markdown]
# # Change the orientation of the dipole!

# %%
Mag_Dipole_Fct = lambda orientation: MagDipole.run(orientation = orientation)

interactive(Mag_Dipole_Fct, orientation=ToggleButtons(options=['X','Z'],value='Z' ))
# Out:
# (<matplotlib.figure.Figure at 0x1079b54d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x10c070d50>)
