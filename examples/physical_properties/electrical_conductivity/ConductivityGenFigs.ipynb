# %%
import numpy as np
import os
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <img src="./IMG_2833.JPG"></img>

# %% [markdown]
# from MINING GEOPHYSICS, VOLUME 2, P. 198

# %%
import matplotlib
matplotlib.rcParams['font.size'] = 16
matplotlib.rcParams['text.usetex'] = True

# %%
ax.spines
# Out:
# {u'bottom': <matplotlib.spines.Spine at 0x1081bd310>,
#  u'left': <matplotlib.spines.Spine at 0x10b125410>,
#  u'right': <matplotlib.spines.Spine at 0x1081bd050>,
#  u'top': <matplotlib.spines.Spine at 0x1081bd9d0>}

# %%
materials = ["COPPER", "GRAPHITE","SEA WATER","GERMANIUM","SILICON", "ROCK SALT", "DISTILLED \n WATER", "MARBLE", "MICA", "PARAFIN", "FUSED QUARTZ"]

# %%
fig, ax = plt.subplots(1,1, figsize = (8,4.5))
ax.set_yticklabels([])
ax.spines[u'top']
ax.set_yticks([])
ax.xaxis.set_ticks_position('bottom')
ax.set_xticks(np.arange(13))
ax.set_xticklabels(['', '6', ' ', '2', ' ', '-2', ' ', '-6', ' ', '-10', ' ', '-14', ' '])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)

ax.text(0.5-0.1,0.15, materials[0], rotation = 90,  verticalalignment='bottom')
ax.text(1.5-0.2,0.15, materials[1], rotation = 90, verticalalignment='bottom')
ax.text(3.5-0.1,0.15, materials[2], rotation = 90,  verticalalignment='bottom')
ax.text(4-0.1,0.15, materials[3], rotation = 90, verticalalignment='bottom')
for i in range (4,8,1):
    ax.text(i+1-0.1,0.15, materials[i], rotation = 90, verticalalignment='bottom')
    
for i in range (8,11,1):
    ax.text(i+1-0.1,0.15, materials[i], rotation = 90, verticalalignment='bottom')
    
ax.set_xlabel("Log Conductivity (S/m)")
for line in ax.xaxis.get_ticklines():
    line.set_markersize(10)
    line.set_markeredgewidth(2)
fig.savefig("./LogCond.png", dpi = 300)

# %%
numx = np.random.random_integers(2, high=8, size=20)/10.*0.5 +0.25
numy = np.random.random_integers(2, high=8, size=20)/10.*0.5 +0.25
numxm = np.random.random_integers(2, high=8, size=20)/10.*0.5 +0.25
numym = np.random.random_integers(2, high=8, size=20)/10.*0.5 +0.25
fig, ax = plt.subplots(1,1, figsize = (8,4.5))
import matplotlib.patches as patches
ax.set_yticks([])
ax.set_xticks([])
ax.add_patch(
    patches.Rectangle(
        (0.25, 0.25),   # (x,y)
        0.5,          # width
        0.5,          # height
        facecolor="black",
        alpha = 0.2
    )
)
for i in range (numx.size):
#     plt.plot(numx[i], numy[i],"k+", markersize = 5)
    plt.scatter(numx[i], numy[i], s = 100, marker ="+", lw = 2, color="k")
    plt.scatter(numx[i], numy[i], s = 120, marker ="o", facecolor="None")
    ax.arrow(numx[i], numy[i], 0.02, 0., head_width=0.02, head_length=0.01, fc='k', ec='k')
for i in range (11):
    plt.plot(np.r_[0.2, 0.22]+0.58, np.ones(2)*(i)*0.05+0.25, 'r-', lw=2)
    plt.scatter(np.r_[0.22], np.ones(1)*(i)*0.05+0.25, s=120, marker="+", lw = 2)    
ax.arrow(0.1, 0.85, 0.85, 0., head_width=0.02, head_length=0.01, fc='k', ec='k')
ax.text(0.34, 0.9, "Applied electric field")
ax.text(0.65, 0.65, "Rock")
plt.scatter(0.35, 0.1, s = 100, marker ="+", lw = 2, color="k")
plt.scatter(0.35, 0.1, s = 120, marker ="o", facecolor="None")
ax.text(0.37, 0.08, ": Electric charge (+)")
ax.set_xlim(0,1)
ax.set_ylim(0,1)
fig.savefig("./Chargeflow.png", dpi = 300)
os.system("open " + "./Chargeflow.png")
# Out:
# 0

# %%
numx = np.random.random_integers(2, high=8, size=10)/10.*0.5 +0.25
numy = np.random.random_integers(2, high=8, size=10)/10.*0.5 +0.35
# numxm = np.random.random_integers(2, high=8, size=20)/10.*0.5 +0.25
# numym = np.random.random_integers(2, high=8, size=20)/10.*0.5 +0.35
numxm_f = np.random.random_integers(2, high=8, size=25)/10.*0.5 +0.3
numym_f = np.random.random_integers(2, high=8, size=25)/10.*0.5 +0.3
numxp_f = np.random.random_integers(2, high=8, size=15)/10.*0.5 +0.3
numyp_f = np.random.random_integers(2, high=8, size=15)/10.*0.5 +0.3
fig, ax = plt.subplots(1,1, figsize = (8,4.5))
import matplotlib.patches as patches
ax.set_yticks([])
ax.set_xticks([])
ax.add_patch(
    patches.Rectangle(
        (0.25, 0.25),   # (x,y)
        0.5,          # width
        0.1,          # height
        facecolor="black",
        alpha = 0.2
    )
)
for i in range (numx.size):
#     plt.plot(numx[i], numy[i],"k+", markersize = 5)
    plt.scatter(numx[i], numy[i], s = 100, marker ="+", lw = 2, color="k")
    plt.scatter(numx[i], numy[i], s = 120, marker ="o", facecolor="None")
for i in range (10):
    plt.plot(np.r_[(i)*0.05+0.265, (i)*0.05+0.265+0.02], np.r_[0.33, 0.33], 'k-', lw=2)
for i in range (5):
#     plt.plot(np.r_[(i)*0.1+0.265, (i)*0.05+0.265+0.02], np.r_[0.33, 0.33], 'r-', lw=2)
    plt.scatter(np.r_[(i)*0.1+0.3], np.r_[0.38], s = 100, marker ="+", lw = 2, color="k")
    plt.scatter(np.r_[(i)*0.1+0.3], np.r_[0.38], s = 120, marker ="o", facecolor="None")
for i in range(numxm_f.size):
    plt.plot(np.r_[numxm_f[i], numxm_f[i]+0.01], np.r_[numym_f[i], numym_f[i]], "r-", lw=2)
for i in range(numxp_f.size):
    plt.scatter(numxp_f[i], numyp_f[i], s = 50, marker ="+", lw = 2, color="b")
ax.plot(np.r_[0.2,1.02], np.ones(2)*0.35, 'k:')

ax.plot(np.ones(2)*0.75, np.r_[0, 1.02], 'k:')
ax.text(0.8, 0.4, "Diffuse layer")
ax.text(0.8, 0.25, "Fixed layer")
ax.text(0.39, 0.08, "CLAY PARTICLE")

plt.scatter(0.8, 0.8, s = 100, marker ="+", lw = 2, color="k")
plt.scatter(0.8, 0.8, s = 120, marker ="o", facecolor="None")
plt.scatter(0.8, 0.75, s = 80, marker ="+", lw = 2, color="b")
plt.plot(np.r_[0.795, 0.795+0.01], np.r_[0.70, 0.70], 'r-',lw=2)

ax.text(0.82, 0.8-0.01, "ABSORBED CATIONS", fontsize = 10)
ax.text(0.82, 0.75-0.01, "NORMAL CATIONS", fontsize = 10)
ax.text(0.82, 0.70-0.01, "NORMAL ANIONS", fontsize = 10)


ax.set_xlim(0.2,1.02)
ax.set_ylim(0,0.9)
fig.savefig("./DoubleLayer.png", dpi = 300)
os.system("open " + "./DoubleLayer.png")
# Out:
# 0
